# %%
import cv2, matplotlib.pyplot as plt, numpy as np

def erode_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load {image_path}"); return
    kernel = np.ones((5,5), np.uint8)
    eroded_img = cv2.erode(img, kernel, iterations=1)
    plt.figure(figsize=(10, 5))
    plt.subplot(121), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)), plt.title('Original')
    plt.subplot(122), plt.imshow(cv2.cvtColor(eroded_img, cv2.COLOR_BGR2RGB)), plt.title('Eroded')
    plt.show()

# erode_image('your_image.jpg')

# %%
erode_image('/content/image6.jpg')
